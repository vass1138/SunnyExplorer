# %% [markdown]
# ## Fix CSV Files
#
# Files were collected on different computers which were setup differently for UTF-8 and UTF-16, and different CSV separators.
#
# Cleaned files use:
# - UTF-8
# - comma as separator
# - missing datetime column heading added
#
# ** This notebook only needs to be run once when processing input files.  All subsequent notebooks will use the cleaned files. **

# %%
import csv
import os
import re
import glob

# %%
def fix_contents(mystring):
    
    contents = [line.replace(';',',') for line in mystring]

    # replace title dd.MM.yyyy with dd/MM/yyyy 
    contents = [line.replace("dd.MM.yyyy","dd/MM/yyyy") for line in contents]
        
    # fix case of HH:mm
    contents = [line.replace("HH:mm","hh:mm") for line in contents]
    
    # replace title HH:mm tt with HH:mm
    contents = [line.replace("hh:mm tt","hh:mm") for line in contents]
    
    # line 7 has the column headings
    # sometimes first field is missing
    # print(contents[7])
    fields = contents[7].split(",")
    if fields[1] == "":
        if fields[2] == "kW":
            fields[0] == "hh:mm tt"
        else:
            fields[0] == "hh:mm"
    
    #print(fields)
    contents[7] = ",".join(fields)
    print(contents[7])
    
    # replace data dd.MM.yyyy with dd/MM/yyyy
    contents = [re.sub(
        pattern=r'(\d{2})\.(\d{2})\.(\d{4})', 
        repl='\\1/\\2/\\3', 
        string=line
    ) for line in contents]
    
    return contents

# %%
def clean_files_in_folder(mypathfilter):
    """
    Open csv as text file.
    Try utf-16 first.
    If that fails, use utf-8.
    Cleanup separators and date formats.
    Save as utf-8.
    """
    
    for f in glob.glob(mypathfilter):

        is_utf8 = False

        # save all output as utf-8
        outfile =  open(os.path.basename(f), 'w', encoding='utf-8')

        print(os.path.basename(f))
        try:
            # skip separator line from start of utf-16 files
            with open(f, 'r', encoding='utf-16', errors='ignore') as infile:
                contents = infile.readlines()[1:]

            contents = fix_contents(contents)

            outfile.writelines(contents)
            outfile.close()

            infile.close()
        except:
            # failed to open file as utf-16, therefore must be utf-8
            is_utf8 = True

        if is_utf8 == True:    
            with open(f, 'r', encoding='utf-8', errors='ignore') as infile:
                contents = infile.readlines()

            contents = fix_contents(contents)
            
            outfile.writelines(contents)
            outfile.close()

            infile.close()

# %%
clean_files_in_folder('data/monthly/Coachmans-*.csv')
# Out:
# Coachmans-20141210.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20141211.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20141212.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160509.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160510.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160511.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160512.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160513.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160514.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160515.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160516.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160517.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160518.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160519.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160520.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160521.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160522.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160523.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160524.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160525.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160526.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160527.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160528.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160529.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160530.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160531.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160601.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160602.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160603.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160604.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160605.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160606.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160607.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160608.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160609.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160610.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160611.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160612.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160613.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160614.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160615.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160616.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160617.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160618.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160619.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160620.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160621.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160622.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160623.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160624.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160625.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160626.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160627.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160628.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160629.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160630.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160701.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160702.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160703.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160704.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160705.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160706.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160707.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160708.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20160709.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170710.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170711.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170712.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170713.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170714.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170715.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170716.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170717.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170718.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170719.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170720.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170721.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170722.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170723.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170724.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170725.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170726.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170727.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170728.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170729.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170730.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170731.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170801.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170802.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170803.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170804.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170805.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170806.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170807.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170808.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170809.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170810.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170811.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170812.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170813.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170814.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170815.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170816.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170817.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170818.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170819.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170820.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170821.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170822.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170823.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170824.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170825.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170826.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170827.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170828.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170829.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170830.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170831.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170901.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170902.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170903.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170904.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170905.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170906.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170907.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20170908.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20190930.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191001.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191002.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191003.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191004.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191005.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191006.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191007.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191008.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191009.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191010.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191011.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191012.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191013.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191014.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191015.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191016.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191017.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191018.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191019.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191020.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191021.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191022.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191023.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20191024.csv
# dd/MM/yyyy hh:mm,kWh,kW
#
# Coachmans-20